// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант №11

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Customer в C#, который будет представлять информацию о
// клиентах или покупателях. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов  должны  быть  реализованы  новые  атрибуты  и  методы,  а  также
// переопределены  некоторые  методы  базового  класса  для  демонстрации
// полиморфизма.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
abstract class Customer
{
    public int CustomerId { get; set; }
    public string Name { get; set; }
    public string Email { get; set; }

    public virtual string GetFullName()
    {
        return Name;
    }

    public virtual void UpdateEmail(string newEmail)
    {
        Email = newEmail;
    }

    public virtual void ViewProfile()
    {
        Console.WriteLine($"ID: {CustomerId}, Имя: {Name}, Email: {Email}");
    }
}

class VipCustomer : Customer
{
    public int LoyaltyPoints { get; set; }

    public override void ViewProfile()
    {
        Console.WriteLine($"ID: {CustomerId}, Имя: {Name}, Email: {Email}, Баланс Лояльности: {LoyaltyPoints}");
    }
}

class RegularCustomer : Customer
{
    public DateTime RegistrationDate { get; set; }
    public DateTime LastEmailUpdate { get; private set; }

    public override void UpdateEmail(string newEmail)
    {
        base.UpdateEmail(newEmail);
        LastEmailUpdate = DateTime.Now;
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"ID: {CustomerId}, Имя: {Name}, Email: {Email}, Зарегистрирован: {RegistrationDate}, Последнее обновление email: {LastEmailUpdate}");
    }
}

class GroupCustomer : Customer
{
    public string GroupName { get; set; }

    public override string GetFullName()
    {
        return GroupName;
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"ID: {CustomerId}, Группа: {GroupName}, Email: {Email}");
    }
}


Customer vip = new VipCustomer { CustomerId = 1, Name = "Никита", Email = "nikita@mail.com", LoyaltyPoints = 120 };
Customer regular = new RegularCustomer { CustomerId = 2, Name = "Егор", Email = "egor@mail.com", RegistrationDate = new DateTime(2022, 5, 1) };
Customer group = new GroupCustomer { CustomerId = 3, GroupName = "Студент", Email = "group@mail.com" };

vip.ViewProfile();
regular.UpdateEmail("egor.new@mail.com");
regular.ViewProfile();
group.ViewProfile();
// Out:
// ID: 1, Имя: Никита, Email: nikita@mail.com, Баланс Лояльности: 120
// ID: 2, Имя: Егор, Email: egor.new@mail.com, Зарегистрирован: 5/1/2022 12:00:00 AM, Последнее обновление email: 9/8/2025 2:43:42 PM
// ID: 3, Группа: Тех команда, Email: group@mail.com
